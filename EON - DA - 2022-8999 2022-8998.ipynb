# %% [markdown]
# # EDA

# %%
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv"
sales_data=pd.read_csv(url)
sales_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
9723 -9697
# Out:
# 26

# %%
# How may values are missing / Nan Values?
sales_data.isna().sum()
# Out:
# Order ID            26
# Product             26
# Quantity Ordered    26
# Price Each          26
# Order Date          26
# Purchase Address    26
# dtype: int64

# %%
sales_data[sales_data.isna().any(axis=1)]
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 664       NaN     NaN              NaN        NaN        NaN              NaN
# 678       NaN     NaN              NaN        NaN        NaN              NaN
# 797       NaN     NaN              NaN        NaN        NaN              NaN
# 876       NaN     NaN              NaN        NaN        NaN              NaN
# 1299      NaN     NaN              NaN        NaN        NaN              NaN
# 1491      NaN     NaN              NaN        NaN        NaN              NaN
# 1699      NaN     NaN              NaN        NaN        NaN              NaN
# 3047      NaN     NaN              NaN        NaN        NaN              NaN
# 3082      NaN     NaN              NaN        NaN        NaN              NaN
# 3584      NaN     NaN              NaN        NaN        NaN              NaN
# 3659      NaN     NaN              NaN        NaN        NaN              NaN
# ...

# %%
# method1:
sales_data_clean=sales_data[~(sales_data.isna().any(axis=1))]

# %%
sales_data_clean.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sales_data_clean.iloc[663:681, :]
# Out:
#     Order ID                   Product Quantity Ordered Price Each  \
# 663   141880    AAA Batteries (4-pack)                2       2.99
# 665   141881    AAA Batteries (4-pack)                7       2.99
# 666   141882     AA Batteries (4-pack)                1       3.84
# 667   141883     AA Batteries (4-pack)                1       3.84
# 668   141884              Google Phone                1        600
# 669   141885          Wired Headphones                1      11.99
# 670   141886                    iPhone                1        700
# 671   141887    AAA Batteries (4-pack)                2       2.99
# 672   141888                    iPhone                1        700
# 673   141889    34in Ultrawide Monitor                1     379.99
# 674   141890  Lightning Charging Cable                1      14.95
# 675   141891      USB-C Charging Cable                1      11.95
# 676   141892     AA Batteries (4-pack)                2       3.84
# ...

# %%
#method2:
sales_data.dropna(axis=0,inplace=True)    #sales_data[~(sales_data.isna().any(axis=1))]

# %%
sales_data["total_price"]=sales_data["Quantity Ordered"].astype('int')*sales_data["Price Each"].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 sales_data["total_price"]=sales_data["Quantity Ordered"].astype('int')*sales_data["Price Each"].astype('float')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
sales_data[sales_data['Quantity Ordered']=='Quantity Ordered']
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3115  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3247  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3612  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3623  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4901  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5593  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 6506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7544  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...

# %%
df=sales_data.drop_duplicates()

# %%
df[df['Quantity Ordered']=='Quantity Ordered']
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 1073  Purchase Address

# %%
sales_data=sales_data[~(sales_data['Quantity Ordered']=='Quantity Ordered')]

# %%
sales_data["total_price"]=sales_data["Quantity Ordered"].astype('int')*sales_data["Price Each"].astype('float')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_1264\3667353131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data["total_price"]=sales_data["Quantity Ordered"].astype('int')*sales_data["Price Each"].astype('float')

# %%
sales_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address  total_price
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215       700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035        14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016        23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001       149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301        11.99

# %%
# find out Highest selling Product from Sales Data

# %%
sales_data['Product'].value_counts().index[0]
# Out:
# 'USB-C Charging Cable'

# %%
# find out lowest selling Product from Sales Data

# %%
sales_data['Product'].value_counts(ascending=True).index[0]
# Out:
# 'LG Dryer'

# %%
sales_data['Product'].value_counts(ascending=True)
# Out:
# LG Dryer                        39
# LG Washing Machine              42
# Vareebadd Phone                124
# 20in Monitor                   213
# ThinkPad Laptop                216
# Macbook Pro Laptop             235
# Flatscreen TV                  243
# 27in 4K Gaming Monitor         312
# 34in Ultrawide Monitor         313
# Google Phone                   317
# iPhone                         379
# 27in FHD Monitor               418
# Bose SoundSport Headphones     656
# Apple Airpods Headphones       809
# Wired Headphones              1005
# AA Batteries (4-pack)         1039
# Lightning Charging Cable      1068
# AAA Batteries (4-pack)        1082
# USB-C Charging Cable          1171
# Name: Product, dtype: int64

# %%
sales_data[sales_data["total_price"]>500]
# Out:
#      Order ID             Product Quantity Ordered Price Each      Order Date  \
# 0      141234              iPhone                1        700  01/22/19 21:25
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 22     141256        Google Phone                1        600  01/29/19 10:40
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# ...       ...                 ...              ...        ...             ...
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9707   150486              iPhone                1        700  01/26/19 15:52
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
# 9722   150501        Google Phone                1        600  01/13/19 16:43
#
# ...

# %%
sales_data['Product'].value_counts(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
print(dir(plt))
# Out:
# ['Annotation', 'Arrow', 'Artist', 'AutoLocator', 'Axes', 'Button', 'Circle', 'Figure', 'FigureCanvasBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MouseButton', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'Number', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotSpec', 'Text', 'TickHelper', 'Widget', '_INSTALL_FIG_OBSERVER', '_IP_REGISTERED', '_IoffContext', '_IonContext', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_api', '_auto_draw_if_interactive', '_backend_mod', '_copy_docstring_and_deprecators', '_get_required_interactive_framework', '_interactive_bk', '_log', '_pylab_helpers', '_setup_pyplot_info_docstrings', '_warn_if_gui_out_of_main_thread', '_xkcd', 'aco
# ...

# %%
sales_data['Product'].value_counts().values
# Out:
# array([1171, 1082, 1068, 1039, 1005,  809,  656,  418,  379,  317,  313,
#         312,  243,  235,  216,  213,  124,   42,   39], dtype=int64)

# %%
plt.hist(x=sales_data['Product'].value_counts())
# Out:
# (array([3., 4., 3., 2., 0., 1., 1., 0., 2., 3.]),
#  array([  39. ,  152.2,  265.4,  378.6,  491.8,  605. ,  718.2,  831.4,
#          944.6, 1057.8, 1171. ]),
#  <BarContainer object of 10 artists>)
